# %%
import pandas as pd

# %%
df1 = pd.read_csv('survey.csv')

# %%
df1.T
# Out:
#                                           0                    1     \
# Timestamp                  2014-08-27 11:29:31  2014-08-27 11:29:37
# Age                                         37                   44
# Gender                                  Female                    M
# Country                          United States        United States
# state                                       IL                   IN
# self_employed                              NaN                  NaN
# family_history                              No                   No
# treatment                                  Yes                   No
# work_interfere                           Often               Rarely
# no_employees                              6-25       More than 1000
# remote_work                                 No                   No
# tech_company                               Yes                   No
# benefits                                   Yes           Don't know
# ...

# %%
df1.benefits = df1.benefits.replace('No', 0)

# %%
df1.benefits = df1.benefits.replace('Yes', 1)

# %%
df1.benefits = df1.benefits.replace('Don\'t know', 2)

# %%
df1.head().T
# Out:
#                                              0                    1  \
# Timestamp                  2014-08-27 11:29:31  2014-08-27 11:29:37
# Age                                         37                   44
# Gender                                  Female                    M
# Country                          United States        United States
# state                                       IL                   IN
# self_employed                              NaN                  NaN
# family_history                              No                   No
# treatment                                  Yes                   No
# work_interfere                           Often               Rarely
# no_employees                              6-25       More than 1000
# remote_work                                 No                   No
# tech_company                               Yes                   No
# benefits                                     1                    2
# ...

# %%
df1.wellness_program = df1.wellness_program.replace('No', 0)
df1.wellness_program = df1.wellness_program.replace('Yes', 1)
df1.wellness_program = df1.wellness_program.replace('Don\'t know', 2)

# %%
df1.seek_help = df1.seek_help.replace('No', 0)
df1.seek_help = df1.seek_help.replace('Yes', 1)
df1.seek_help = df1.seek_help.replace('Don\'t know', 2)

# %%
df1.anonymity = df1.anonymity.replace('No', 0)
df1.anonymity = df1.anonymity.replace('Yes', 1)
df1.anonymity = df1.anonymity.replace('Don\'t know', 2)

# %%
df1.mental_vs_physical = df1.mental_vs_physical.replace('No', 0)
df1.mental_vs_physical = df1.mental_vs_physical.replace('Yes', 1)
df1.mental_vs_physical = df1.mental_vs_physical.replace('Don\'t know', 2)

# %%
df1.head().T
# Out:
#                                              0                    1  \
# Timestamp                  2014-08-27 11:29:31  2014-08-27 11:29:37
# Age                                         37                   44
# Gender                                  Female                    M
# Country                          United States        United States
# state                                       IL                   IN
# self_employed                              NaN                  NaN
# family_history                              No                   No
# treatment                                  Yes                   No
# work_interfere                           Often               Rarely
# no_employees                              6-25       More than 1000
# remote_work                                 No                   No
# tech_company                               Yes                   No
# benefits                                     1                    2
# ...

# %%
df1.to_csv('survey.csv')
